# %%
def extract_text_from_pdf(pdf_path):
    import fitz

    document = fitz.open(pdf_path)

    all_text = ""

    for page in document:
        all_text += page.get_text()

    return all_text

# %%
pdf_path = "../data/Policies/KYC_Policy.pdf"

all_text = extract_text_from_pdf(pdf_path)

# %%
import sys

# !{sys.executable} -m pip install langchain --user
# !{sys.executable} -m pip install langchain-text-splitters --user
# Out:
# Requirement already satisfied: langchain in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (1.3.11)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.7 in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from langchain) (1.4.8)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.5 in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from langchain) (1.2.7)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\programdata\anaconda3\lib\site-packages (from langchain) (2.10.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (0.9.4)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (9.0.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (0.16.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\programdata\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.7->langchain) (2.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (3.8.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\programdata\anaconda3\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (15.0.1)
# Requirement already satisfied: anyio>=3.5.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (4.7.0)
# Requirement already satisfied: distro>=1.7.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (1.3.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (0.23.0)
# Requirement already satisfied: certifi in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (2.5.0)
# Requirement already satisfied: langchain-text-splitters in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (1.1.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from langchain-text-splitters) (1.4.8)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.9.4)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (26.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.10.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (9.0.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.16.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\programdata\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.1)
# Requirement already satisfied: anyio>=3.5.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.7.0)
# Requirement already satisfied: distro>=1.7.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.3.0)
# Requirement already satisfied: websockets>=15.0 in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.8.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.23.0)
# Requirement already satisfied: certifi in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: idna in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.27.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aishwarya\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.5.0)

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

print("LangChain installed successfully!")
# Out:
# LangChain installed successfully!

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200,
    separators=["\n\n", "\n", ". ", " ", ""]
)

# %%
chunks = text_splitter.split_text(all_text)

# %%
print("Number of chunks:", len(chunks))
# Out:
# Number of chunks: 16

# %%
print(chunks[0])
# Out:
# ABC NATIONAL BANK
# Internal Policy Document
# KNOW YOUR CUSTOMER (KYC) POLICY
#
# Document Title
# Know Your Customer (KYC) Policy
# Bank Name
# ABC National Bank
# Version
# 1.0
# Effective Date
# January 2025
# Document Owner
# Compliance Department
# Confidentiality
# Internal Use Only
#
# CONFIDENTIALITY: INTERNAL USE ONLY
# This document contains confidential and proprietary information of ABC National Bank. Unauthorized distribution, reproduction, or disclosure
# outside the Bank is strictly prohibited.
#
#
# ABC National Bank – Know Your Customer (KYC) Policy
# Internal Use Only
# Version 1.0  |  Effective January 2025  |  Page 2 of 6
# 1. Purpose
# The purpose of this Know Your Customer (KYC) Policy (“Policy”) is to establish a comprehensive and standardized
# framework for the identification and verification of customers of ABC National Bank (“the Bank”) prior to and
# throughout the course of a banking relationship. This Policy is designed to prevent the Bank from being used,

# %%
print(chunks[1])
# Out:
# throughout the course of a banking relationship. This Policy is designed to prevent the Bank from being used,
# intentionally or unintentionally, for money laundering, terrorist financing, and other financial crimes, while ensuring full
# compliance with the Reserve Bank of India (RBI) KYC Master Direction and other applicable regulatory requirements.
# The Policy further aims to safeguard the Bank's reputation, protect customer interests, and promote sound corporate
# governance across all business lines.
# 2. Scope
# This Policy applies to all branches, departments, subsidiaries, employees, officers, and authorized business
# correspondents of ABC National Bank, without exception, and covers every category of customer relationship, including
# but not limited to:
# • Individual and joint savings and current account holders
# • Non-Resident Indian (NRI) and Foreign National account holders
# • Sole proprietorships, partnerships, companies, trusts, and societies

# %%
for i, chunk in enumerate(chunks):
    print(f"Chunk {i+1}: {len(chunk)} characters")
# Out:
# Chunk 1: 977 characters
# Chunk 2: 965 characters
# Chunk 3: 980 characters
# Chunk 4: 994 characters
# Chunk 5: 904 characters
# Chunk 6: 971 characters
# Chunk 7: 931 characters
# Chunk 8: 993 characters
# Chunk 9: 977 characters
# Chunk 10: 970 characters
# Chunk 11: 925 characters
# Chunk 12: 967 characters
# Chunk 13: 983 characters
# Chunk 14: 972 characters
# Chunk 15: 980 characters
# Chunk 16: 256 characters
