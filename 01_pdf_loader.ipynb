# %%
import fitz
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\Aishwarya\OneDrive\Desktop\PS068_Regulatory_Change_Assistant\Notebooks

# %%
os.listdir("../data")
# Out:
# ['Controls', 'Forms', 'Policies', 'Regulations', 'SOPS']

# %%
os.listdir("../data/policies")
# Out:
# ['.ipynb_checkpoints',
#  'AML_Policy.pdf',
#  'Information_Security_Policy.pdf',
#  'KYC_Policy.pdf']

# %%
pdf_path = "../data/Policies/KYC_Policy.pdf"

# %%
document = fitz.open(pdf_path)

# %%
len(document)
# Out:
# 6

# %%
page = document[0]

# %%
text = page.get_text()

# %%
print(text)
# Out:
#
# ABC NATIONAL BANK
# Internal Policy Document
# KNOW YOUR CUSTOMER (KYC) POLICY
#
# Document Title
# Know Your Customer (KYC) Policy
# Bank Name
# ABC National Bank
# Version
# 1.0
# Effective Date
# January 2025
# Document Owner
# Compliance Department
# Confidentiality
# Internal Use Only
#
# CONFIDENTIALITY: INTERNAL USE ONLY
# This document contains confidential and proprietary information of ABC National Bank. Unauthorized distribution, reproduction, or disclosure
# outside the Bank is strictly prohibited.

# %%
for page in document:
    print(page)
# Out:
# page 0 of <../data/Policies/KYC_Policy.pdf, doc# 1>
# page 1 of <../data/Policies/KYC_Policy.pdf, doc# 1>
# page 2 of <../data/Policies/KYC_Policy.pdf, doc# 1>
# page 3 of <../data/Policies/KYC_Policy.pdf, doc# 1>
# page 4 of <../data/Policies/KYC_Policy.pdf, doc# 1>
# page 5 of <../data/Policies/KYC_Policy.pdf, doc# 1>

# %%
all_text = ""

# %%
for page in document:
    all_text += page.get_text()

# %%
print(all_text)
# Out:
#
# ABC NATIONAL BANK
# Internal Policy Document
# KNOW YOUR CUSTOMER (KYC) POLICY
#
# Document Title
# Know Your Customer (KYC) Policy
# Bank Name
# ABC National Bank
# Version
# 1.0
# Effective Date
# January 2025
# Document Owner
# Compliance Department
# Confidentiality
# Internal Use Only
#
# CONFIDENTIALITY: INTERNAL USE ONLY
# This document contains confidential and proprietary information of ABC National Bank. Unauthorized distribution, reproduction, or disclosure
# outside the Bank is strictly prohibited.
#
#
# ABC National Bank – Know Your Customer (KYC) Policy
# Internal Use Only
# Version 1.0  |  Effective January 2025  |  Page 2 of 6
# 1. Purpose
# The purpose of this Know Your Customer (KYC) Policy (“Policy”) is to establish a comprehensive and standardized
# framework for the identification and verification of customers of ABC National Bank (“the Bank”) prior to and
# ...

# %%
len(all_text)
# Out:
# 12413
